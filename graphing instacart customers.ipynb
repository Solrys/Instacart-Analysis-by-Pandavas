# %%
# for basic mathematics operation 
import numpy as np
import pandas as pd
from pandas import plotting

# for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# for interactive visualizations
import plotly.offline as py
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
from plotly import tools
init_notebook_mode(connected = True)
import plotly.figure_factory as ff

# for path
import os
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# importing the dataset
data = pd.read_csv('instacart_customer.csv')

dat = ff.create_table(data.head())

py.iplot(dat)
# Out:
# <div>                            <div id="cc462d6d-f155-475a-977c-a82495a27675" class="plotly-graph-div" style="height:230px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc462d6d-f155-475a-977c-a82495a27675")) {                    Plotly.newPlot(                        "cc462d6d-f155-475a-977c-a82495a27675",                        [{"colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "hoverinfo": "none", "opacity": 0.75, "showscale": false, "type": "heatmap", "z": [[0, 0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5, 0.5]]}],                        {"annotations": [{"align": "left", "font": {"color": "#ffffff"}, "showarrow": false, "text": "<b>user_id</b>", "x": -0.45, "xanchor": "left", "xref": "x", "y":
# ...

# %%
data.dtypes
# Out:
# user_id             int64
# gender             object
# age               float64
# income            float64
# customer score    float64
# dtype: object

# %%
m=(data.dtypes=='float')
data.loc[:,m]=data.loc[:,m].astype(int)
data.head()
# Out:
#    user_id  gender  age  income  customer score
# 0        1    Male   55  112000              11
# 1        3    Male   68   70000              13
# 2        5  Female   58   51000               5
# 3        8  Female   62   71000               4
# 4       12  Female   40   71000               6

# %%
#Save New File
output_file_path = "in_cart_customer.csv"
data.to_csv(output_file_path, index=False)

# %%
plt.rcParams['figure.figsize'] = (15, 10)


plotting.andrews_curves(data.drop("user_id", axis=1), "gender")
plt.title('Andrew Curves for Gender', fontsize = 20)
plt.show()

# %% [markdown]
# It has been shown the Andrews curves are able to preserve means, distance (up to a constant) and variances. Which means that Andrews curves that are represented by functions close together suggest that the corresponding data points will also be close together

# %%
labels = ['Female', 'Male']
size = data['gender'].value_counts()
colors = ['pink', 'lightblue']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('gender', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
x = data['income']
y = data['age']
z = data['customer score']

sns.lineplot(x, y, color = 'blue')
sns.lineplot(x, z, color = 'pink')
plt.title('Annual Income vs Age and Spending Score', fontsize = 20)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (18, 8)

plt.subplot(1, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(data['income'])
plt.title('Distribution of Annual Income', fontsize = 20)
plt.xlabel('Range of Annual Income')
plt.ylabel('Count')


plt.subplot(1, 2, 2)
sns.set(style = 'whitegrid')
sns.distplot(data['age'], color = 'red')
plt.title('Distribution of Age', fontsize = 20)
plt.xlabel('Range of Age')
plt.ylabel('Count')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.countplot(data['income'], palette = 'hsv')
plt.title('Distribution of Income', fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.countplot(data['age'], palette = 'hsv')
plt.title('Distribution of Age', fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 8)
sns.countplot(data['customer score'], palette = 'copper')
plt.title('Distribution of Customer Score', fontsize = 20)
plt.show()

# %%
sns.pairplot(data)
plt.title('Overview of the Data', fontsize = 20)
plt.show()

# %%
#  Gender vs Spendscore

plt.rcParams['figure.figsize'] = (18, 7)
sns.boxenplot(data['gender'], data['customer score'], palette = 'Greens')
plt.title('Gender vs Spending Score', fontsize = 20)
plt.show()

# %%
x = data.iloc[:, [3, 4]].values

# let's check the shape of x
print(x.shape)
# Out:
# (12950, 2)
